# %% [markdown]
# #Useful NLP Libraries & Networks

# %% [markdown]
# # question 1: compare and contrast nltk and spacy in terms of features, ease of use, and performance.
#
# # answer:
#
# # nltk:
# # - mainly used for learning and research.
# # - provides many nlp algorithms.
# # - easy for beginners.
# # - slower for large datasets.
#
# # spacy:
# # - designed for production applications.
# # - faster and more efficient.
# # - provides tokenization, lemmatization, and named entity recognition.
# # - easy to integrate into real-world projects.
#
# # comparison:
# # nltk is best for education and experimentation, while spacy is best for
# # industrial and production-level nlp applications.

# %% [markdown]
# # question 2: what is textblob and how does it simplify common nlp tasks like sentiment analysis and translation?
#
# # answer:
#
# # textblob is a simple python library for natural language processing.
# #
# # features:
# # - sentiment analysis
# # - translation
# # - spell correction
# # - noun phrase extraction
# # - part-of-speech tagging
# #
# # it provides an easy interface for beginners and requires very little code.

# %% [markdown]
# # question 3: explain the role of stanford nlp in academic and industry nlp projects.
#
# # answer:
#
# # stanford nlp is a powerful natural language processing toolkit.
# #
# # roles:
# # - text analysis
# # - tokenization
# # - parsing
# # - named entity recognition
# # - sentiment analysis
# # - dependency parsing
# #
# # it is widely used in research and industrial applications because of its
# # high accuracy.

# %% [markdown]
# # question 4: describe the architecture and functioning of a recurrent neural network (rnn).
#
# # answer:
#
# # rnn is a neural network designed for sequential data.
# #
# # architecture:
# # - input layer
# # - hidden layer with memory
# # - output layer
# #
# # working:
# # - processes one word at a time.
# # - remembers previous information.
# # - passes hidden states to future time steps.
# #
# # applications:
# # - text generation
# # - language translation
# # - speech recognition
# # - sentiment analysis

# %% [markdown]
# # question 5: what is the key difference between lstm and gru networks in nlp applications?
#
# # answer:
#
# # lstm:
# # - has input, output, and forget gates.
# # - handles long-term dependencies better.
# # - more parameters and slower.
#
# # gru:
# # - has update and reset gates.
# # - simpler architecture.
# # - faster to train.
# # - requires less memory.
#
# # both are used for sequence prediction tasks.

# %% [markdown]
# #Question 6: Write a Python program using TextBlob to perform sentiment analysis on the following paragraph of text:

# %%
# !pip install -q textblob

from textblob import TextBlob

text = """
i had a great experience using the new mobile banking app.
the interface is intuitive, and customer support was quick to resolve my issue.
however, the app did crash once during a transaction, which was frustrating.
"""

blob = TextBlob(text)

print("polarity:", blob.sentiment.polarity)
print("subjectivity:", blob.sentiment.subjectivity)
# Out:
# polarity: 0.21742424242424244
# subjectivity: 0.6511363636363636

# %% [markdown]
# #Question 7: Given the sample paragraph below, perform string tokenization and frequency distribution using Python and NLTK:

# %%
# !pip install -q nltk

import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")

from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

text = """
natural language processing (nlp) is a fascinating field that combines linguistics,
computer science, and artificial intelligence.
"""

tokens = word_tokenize(text)

print("tokens:")
print(tokens)

fdist = FreqDist(tokens)

print("\nfrequency distribution:")
print(fdist.most_common(10))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# tokens:
# ['natural', 'language', 'processing', '(', 'nlp', ')', 'is', 'a', 'fascinating', 'field', 'that', 'combines', 'linguistics', ',', 'computer', 'science', ',', 'and', 'artificial', 'intelligence', '.']
#
# frequency distribution:
# [(',', 2), ('natural', 1), ('language', 1), ('processing', 1), ('(', 1), ('nlp', 1), (')', 1), ('is', 1), ('a', 1), ('fascinating', 1)]
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# #Question 8: Implement a basic LSTM model in Keras for a text classification task using the following dummy dataset. Your model should classify sentences as either positive (1) or negative (0).

# %%
import numpy as np
import tensorflow as tf # Added TensorFlow import
# !pip install -q tensorflow

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

texts = [
    "i love this project",
    "this is an amazing experience",
    "i hate waiting in line",
    "this is the worst service",
    "absolutely fantastic"
]

labels = [1,1,0,0,1]

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

seq = tokenizer.texts_to_sequences(texts)
pad = pad_sequences(seq)

# Convert labels to a NumPy array
labels = np.array(labels)

# Convert pad and labels to TensorFlow Tensors to ensure compatibility
pad = tf.constant(pad)
labels = tf.constant(labels)

model = Sequential([
    Embedding(100,16),
    LSTM(16),
    Dense(1,activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.fit(pad,labels,epochs=20,verbose=1)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6000 - loss: 0.6922
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.6908
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6000 - loss: 0.6894
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6000 - loss: 0.6880
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6000 - loss: 0.6866
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6000 - loss: 0.6851
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6000 - loss: 0.6837
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6000 - loss: 0.6822
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6000 - loss: 0.6806
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6000 - loss: 0.6790
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6000 - loss: 0.6774
# Epoch 12/20
# ...

# %% [markdown]
# #Question 9: Using spaCy, build a simple NLP pipeline that includes tokenization, lemmatization, and entity recognition. Use the following paragraph as your dataset:

# %%
# !pip install -q spacy

# !python -m spacy download en_core_web_sm

import spacy

nlp = spacy.load("en_core_web_sm")

text = """
homi jehangir bhabha was an indian nuclear physicist.
he founded the tata institute of fundamental research.
"""

doc = nlp(text)

print("tokens and lemmas:")

for token in doc:
    print(token.text,"->",token.lemma_)

print("\nnamed entities:")

for ent in doc.ents:
    print(ent.text,"-",ent.label_)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 104.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# tokens and lemmas:
#
#  ->
#
# homi -> homi
# jehangir -> jehangir
# bhabha -> bhabha
# was -> be
# an -> an
# indian -> indian
# nuclear -> nuclear
# physicist -> physicist
# . -> .
#
#  ->
#
# he -> he
# founded -> found
# the -> the
# tata -> tata
# institute -> institute
# of -> of
# fundamental -> fundamental
# research -> research
# . -> .
#
#  ->
#
#
# named entities:
# jehangir bhabha - ORG
# indian - NORP
# the tata institute of fundamental research - ORG

# %% [markdown]
# # question 10: chatbot for a mental health platform.
#
# # answer:
#
# # architecture:
# # - collect user messages.
# # - preprocess text using spacy or stanford nlp.
# # - tokenize and clean the text.
# # - use lstm or gru to understand the conversation context.
# # - generate responses using a trained language model.
# #
# # preprocessing:
# # - tokenization
# # - stopword removal
# # - lemmatization
# # - named entity recognition
# #
# # ethical considerations:
# # - protect user privacy.
# # - avoid biased responses.
# # - keep conversations confidential.
# # - recommend professional help in emergencies.
# # - monitor harmful or suicidal content carefully.
